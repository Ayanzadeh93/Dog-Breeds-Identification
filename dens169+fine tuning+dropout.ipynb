# %%
from keras.layers import Dropout

# %%
# -*- coding: utf-8 -*-
# -*- coding: utf-8 -*-

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
#config.gpu_options.visible_device_list = "0"
set_session(tf.Session(config=config))
from keras.optimizers import SGD
from keras.layers import Input, merge, ZeroPadding2D
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model
import keras.backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import keras
from keras.applications.vgg19 import VGG19
from keras.models import Model
from keras.layers import Dense, Dropout, Flatten

import os
from tqdm import tqdm
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import cv2

from custom_layers.scale_layer import Scale

from subprocess import check_output


from sklearn.metrics import log_loss

from custom_layers.scale_layer import Scale

#from load_cifar10 import load_cifar10_data

def densenet169_model(img_rows, img_cols, color_type=1, nb_dense_block=4, growth_rate=32, nb_filter=64, reduction=0.5, dropout_rate=0.0, weight_decay=1e-4, num_classes=None):
    '''
    DenseNet 169 Model for Keras
    Model Schema is based on 
    https://github.com/flyyufelix/DenseNet-Keras
    ImageNet Pretrained Weights 
    Theano: https://drive.google.com/open?id=0Byy2AcGyEVxfN0d3T1F1MXg0NlU
    TensorFlow: https://drive.google.com/open?id=0Byy2AcGyEVxfSEc5UC1ROUFJdmM
    # Arguments
        nb_dense_block: number of dense blocks to add to end
        growth_rate: number of filters to add per dense block
        nb_filter: initial number of filters
        reduction: reduction factor of transition blocks.
        dropout_rate: dropout rate
        weight_decay: weight decay factor
        classes: optional number of classes to classify images
        weights_path: path to pre-trained weights
    # Returns
        A Keras model instance.
    '''
    eps = 1.1e-5

    # compute compression factor
    compression = 1.0 - reduction

    # Handle Dimension Ordering for different backends
    global concat_axis
    if K.image_dim_ordering() == 'tf':
      concat_axis = 3
      img_input = Input(shape=(224, 224, 3), name='data')
    else:
      concat_axis = 1
      img_input = Input(shape=(3, 224, 224), name='data')

    # From architecture for ImageNet (Table 1 in the paper)
    nb_filter = 64
    nb_layers = [6,12,32,32] # For DenseNet-169

    # Initial convolution
    x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(img_input)
    x = Convolution2D(nb_filter, 7, 7, subsample=(2, 2), name='conv1', bias=False)(x)
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name='conv1_bn')(x)
    x = Scale(axis=concat_axis, name='conv1_scale')(x)
    x = Activation('relu', name='relu1')(x)
    x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)

    # Add dense blocks
    for block_idx in range(nb_dense_block - 1):
        stage = block_idx+2
        x, nb_filter = dense_block(x, stage, nb_layers[block_idx], nb_filter, growth_rate, dropout_rate=dropout_rate, weight_decay=weight_decay)

        # Add transition_block
        x = transition_block(x, stage, nb_filter, compression=compression, dropout_rate=dropout_rate, weight_decay=weight_decay)
        nb_filter = int(nb_filter * compression)

    final_stage = stage + 1
    x, nb_filter = dense_block(x, final_stage, nb_layers[-1], nb_filter, growth_rate, dropout_rate=dropout_rate, weight_decay=weight_decay)

    x = BatchNormalization(epsilon=eps, axis=concat_axis, name='conv'+str(final_stage)+'_blk_bn')(x)
    x = Scale(axis=concat_axis, name='conv'+str(final_stage)+'_blk_scale')(x)
    x = Activation('relu', name='relu'+str(final_stage)+'_blk')(x)

    x_fc = GlobalAveragePooling2D(name='pool'+str(final_stage))(x)
    x_fc = Dense(1000, name='fc6')(x_fc)
    x_fc = Activation('softmax', name='prob')(x_fc)

    model = Model(img_input, x_fc, name='densenet')

    if K.image_dim_ordering() == 'th':
      # Use pre-trained weights for Theano backend
      weights_path = 'imagenet_models/densenet169_weights_th.h5'
    else:
      # Use pre-trained weights for Tensorflow backend
      weights_path = 'imagenet_models/densenet169_weights_tf.h5'

    model.load_weights(weights_path, by_name=True)
    
    for layer in model.layers[:-4]:
        layer.trainable = False
    # Truncate and replace softmax layer for transfer learning
    # Cannot use model.layers.pop() since model is not of Sequential() type
    # The method below works since pre-trained weights are stored in layers but not in the model
    x_newfc = GlobalAveragePooling2D(name='pool'+str(final_stage))(x)
    x_newfc = Dense(num_classes, name='fc6')(x_newfc)
    x_newfc = Dropout(0.2)(x_newfc)
    x_newfc = Activation('softmax', name='prob')(x_newfc)

    model = Model(img_input, x_newfc)

    # Learning rate is changed to 0.001
    sgd = SGD(lr=1e-3, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

    return model


def conv_block(x, stage, branch, nb_filter, dropout_rate=None, weight_decay=1e-4):
    '''Apply BatchNorm, Relu, bottleneck 1x1 Conv2D, 3x3 Conv2D, and option dropout
        # Arguments
            x: input tensor 
            stage: index for dense block
            branch: layer index within each dense block
            nb_filter: number of filters
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    '''
    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_' + str(branch)
    relu_name_base = 'relu' + str(stage) + '_' + str(branch)

    # 1x1 Convolution (Bottleneck layer)
    inter_channel = nb_filter * 4  
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_x1_bn')(x)
    x = Scale(axis=concat_axis, name=conv_name_base+'_x1_scale')(x)
    x = Activation('relu', name=relu_name_base+'_x1')(x)
    x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    # 3x3 Convolution
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_x2_bn')(x)
    x = Scale(axis=concat_axis, name=conv_name_base+'_x2_scale')(x)
    x = Activation('relu', name=relu_name_base+'_x2')(x)
    x = ZeroPadding2D((1, 1), name=conv_name_base+'_x2_zeropadding')(x)
    x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x


def transition_block(x, stage, nb_filter, compression=1.0, dropout_rate=None, weight_decay=1E-4):
    ''' Apply BatchNorm, 1x1 Convolution, averagePooling, optional compression, dropout 
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_filter: number of filters
            compression: calculated as 1 - reduction. Reduces the number of feature maps in the transition block.
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    '''

    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_blk'
    relu_name_base = 'relu' + str(stage) + '_blk'
    pool_name_base = 'pool' + str(stage) 

    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_bn')(x)
    x = Scale(axis=concat_axis, name=conv_name_base+'_scale')(x)
    x = Activation('relu', name=relu_name_base)(x)
    x = Convolution2D(int(nb_filter * compression), 1, 1, name=conv_name_base, bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    x = AveragePooling2D((2, 2), strides=(2, 2), name=pool_name_base)(x)

    return x


def dense_block(x, stage, nb_layers, nb_filter, growth_rate, dropout_rate=None, weight_decay=1e-4, grow_nb_filters=True):
    ''' Build a dense_block where the output of each conv_block is fed to subsequent ones
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_layers: the number of layers of conv_block to append to the model.
            nb_filter: number of filters
            growth_rate: growth rate
            dropout_rate: dropout rate
            weight_decay: weight decay factor
            grow_nb_filters: flag to decide to allow number of filters to grow
    '''

    eps = 1.1e-5
    concat_feat = x

    for i in range(nb_layers):
        branch = i+1
        x = conv_block(concat_feat, stage, branch, growth_rate, dropout_rate, weight_decay)
        concat_feat = merge([concat_feat, x], mode='concat', concat_axis=concat_axis, name='concat_'+str(stage)+'_'+str(branch))

        if grow_nb_filters:
            nb_filter += growth_rate

    return concat_feat, nb_filter

if __name__ == '__main__':

    # Example to fine-tune on 3000 samples from Cifar10

    img_rows, img_cols = 224, 224 # Resolution of inputs
    channel = 3
    num_classes = 120
    batch_size = 32
    nb_epoch = 50
    
    directory_path = "/storage/aydin/kaggle-dog/Kaggle-dog-breeds-classification/cnn_finetune-master/"
    
    print(check_output(["ls", directory_path]).decode("utf8"))

    df_train = pd.read_csv(directory_path+'labels.csv')
    df_test = pd.read_csv(directory_path+'sample_submission.csv')

    targets_series = pd.Series(df_train['breed'])
    one_hot = pd.get_dummies(targets_series, sparse = True)

    one_hot_labels = np.asarray(one_hot)

    im_size = 224
    x_train = []
    y_train = []
    x_test = []

    i = 0 
    for f, breed in tqdm(df_train.values):
        img = cv2.imread(directory_path+'train/{}.jpg'.format(f))
        label = one_hot_labels[i]
        x_train.append(cv2.resize(img, (im_size, im_size)))
        y_train.append(label)
        i += 1


    for f in tqdm(df_test['id'].values):
        img = cv2.imread(directory_path+'test/{}.jpg'.format(f))
        x_test.append(cv2.resize(img, (im_size, im_size)))

    y_train_raw = np.array(y_train, np.uint8)
    x_train_raw = np.array(x_train, np.float32) / 255.
    x_test  = np.array(x_test, np.float32) / 255.

    print(x_train_raw.shape)
    print(y_train_raw.shape)
    print(x_test.shape)

    num_class = y_train_raw.shape[1]

    # Load Cifar10 data. Please implement your own load_data() module for your own dataset
    #X_train, Y_train, X_valid, Y_valid = load_cifar10_data(img_rows, img_cols)
    
    X_train, X_valid, Y_train, Y_valid = train_test_split(x_train_raw, y_train_raw, test_size=0.3, random_state=1)
    

    # Load our model
    model = densenet169_model(img_rows=img_rows, img_cols=img_cols, color_type=channel, num_classes=num_classes)

    # Start Fine-tuning
    model.fit(X_train, Y_train,
              batch_size=batch_size,
              nb_epoch=nb_epoch,
              shuffle=True,
              verbose=1,
              validation_data=(X_valid, Y_valid),
              )

    # Make predictions
    predictions_valid = model.predict(X_valid, batch_size=batch_size, verbose=1)

    # Cross-entropy loss score
    score = log_loss(Y_valid, predictions_valid)
# Out:
# /storage/omid/venv3/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /storage/omid/venv3/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# custom_layers
# data_gen
# dens121.ipynb
# dense169.ipynb
# densenet121.py
# densenet161.py
# densenet169.py
# denset201.ipynb
# googlenet.ipynb
# googlenet.py
# imagenet_models
# inception v3.ipynb
# inception_v3.py
# INCEPTION_v3_starter.ipynb
# inception_v4.py
# inception_version4.ipynb
# keras_VGG19_without pretrain.ipynb
# labels.csv
# LICENSE
# load_cifar10.py
# load_cifar10.pyc
# mixed.ipynb
# README.md
# resnet101.ipynb
# resnet_101.py
# resnet-151.ipynb
# resnet_152.py
# resnet50.ipynb
# resnet_50.py
# result-2.csv
# result-3.csv
# result-4.csv
# result-5.csv
# result-6.csv
# result-8.csv
# sample_submission.csv
# test
# train
# untitled
# Untitled1.ipynb
# Untitled.ipynb
# vgg16.py
# VGG19.ipynb
# vgg19.py
# view
# 100%|██████████| 10222/10222 [00:37<00:00, 269.12it/s]
# 100%|██████████| 10357/10357 [00:30<00:00, 338.56it/s]
# (10222, 224, 224, 3)
# (10222, 120)
# (10357, 224, 224, 3)
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:84: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (7, 7), use_bias=False, strides=(2, 2), name="conv1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_1_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_1_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:226: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /storage/omid/venv3/lib/python3.5/site-packages/Keras-2.1.2-py3.5.egg/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_2_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_2_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_3_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_3_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_4_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_4_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_5_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_5_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_6_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_6_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:197: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_blk")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_1_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_1_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_2_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_2_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_3_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_3_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_4_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_4_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_5_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_5_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_6_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_6_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_7_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_7_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_8_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_8_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_9_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_9_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_10_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_10_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_11_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_11_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_12_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_12_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:197: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="conv3_blk")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_1_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_1_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_2_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_2_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_3_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_3_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_4_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_4_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_5_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_5_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_6_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_6_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_7_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_7_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_8_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_8_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_9_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_9_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_10_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_10_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_11_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_11_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_12_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_12_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_13_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_13_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_14_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_14_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_15_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_15_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_16_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_16_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_17_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_17_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_18_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_18_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_19_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_19_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_20_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_20_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_21_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_21_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_22_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_22_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_23_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_23_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_24_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_24_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_25_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_25_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_26_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_26_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_27_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_27_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_28_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_28_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_29_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_29_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_30_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_30_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_31_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_31_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_32_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_32_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:197: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(640, (1, 1), use_bias=False, name="conv4_blk")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_1_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_1_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_2_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_2_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_3_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_3_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_4_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_4_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_5_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_5_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_6_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_6_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_7_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_7_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_8_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_8_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_9_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_9_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_10_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_10_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_11_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_11_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_12_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_12_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_13_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_13_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_14_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_14_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_15_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_15_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_16_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_16_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_17_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_17_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_18_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_18_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_19_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_19_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_20_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_20_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_21_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_21_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_22_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_22_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_23_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_23_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_24_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_24_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_25_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_25_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_26_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_26_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_27_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_27_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_28_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_28_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_29_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_29_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_30_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_30_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_31_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_31_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_32_x1")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:170: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_32_x2")`
# /storage/omid/venv3/lib/python3.5/site-packages/ipykernel_launcher.py:298: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 7155 samples, validate on 3067 samples
# Epoch 1/50
# 7155/7155 [==============================] - 272s 38ms/step - loss: 4.2551 - acc: 0.1326 - val_loss: 3.2691 - val_acc: 0.3668
# Epoch 2/50
# 7155/7155 [==============================] - 277s 39ms/step - loss: 2.9532 - acc: 0.4324 - val_loss: 2.3163 - val_acc: 0.5921
# Epoch 3/50
# 7155/7155 [==============================] - 277s 39ms/step - loss: 2.3192 - acc: 0.5632 - val_loss: 1.8258 - val_acc: 0.6824
# Epoch 4/50
# 7155/7155 [==============================] - 278s 39ms/step - loss: 2.0233 - acc: 0.6099 - val_loss: 1.5532 - val_acc: 0.7268
# Epoch 5/50
# 7155/7155 [==============================] - 278s 39ms/step - loss: 1.8156 - acc: 0.6474 - val_loss: 1.3766 - val_acc: 0.7414
# Epoch 6/50
# 7155/7155 [==============================] - 273s 38ms/step - loss: 1.7297 - acc: 0.6553 - val_loss: 1.2640 - val_acc: 0.7535
# Epoch 7/50
# 7155/7155 [==============================] - 246s 34ms/step - loss: 1.6491 - acc: 0.6686 - val_loss: 1.1769 - val_acc: 0.7636
# Epoch 8/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.5519 - acc: 0.6893 - val_loss: 1.1051 - val_acc: 0.7757
# Epoch 9/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.5206 - acc: 0.6887 - val_loss: 1.0601 - val_acc: 0.7793
# Epoch 10/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.4662 - acc: 0.6999 - val_loss: 1.0169 - val_acc: 0.7799
# Epoch 11/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.4567 - acc: 0.7001 - val_loss: 0.9818 - val_acc: 0.7871
# Epoch 12/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.3782 - acc: 0.7188 - val_loss: 0.9586 - val_acc: 0.7848
# Epoch 13/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.3393 - acc: 0.7270 - val_loss: 0.9335 - val_acc: 0.7923
# Epoch 14/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.3535 - acc: 0.7201 - val_loss: 0.9151 - val_acc: 0.7946
# Epoch 15/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.2900 - acc: 0.7314 - val_loss: 0.8961 - val_acc: 0.8008
# Epoch 16/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.2737 - acc: 0.7332 - val_loss: 0.8821 - val_acc: 0.7952
# Epoch 17/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.2517 - acc: 0.7417 - val_loss: 0.8657 - val_acc: 0.7975
# Epoch 18/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.2667 - acc: 0.7361 - val_loss: 0.8531 - val_acc: 0.7995
# Epoch 19/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.2355 - acc: 0.7435 - val_loss: 0.8466 - val_acc: 0.7995
# Epoch 20/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.2539 - acc: 0.7360 - val_loss: 0.8366 - val_acc: 0.7982
# Epoch 21/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.1814 - acc: 0.7494 - val_loss: 0.8247 - val_acc: 0.8031
# Epoch 22/50
# 7155/7155 [==============================] - 203s 28ms/step - loss: 1.2116 - acc: 0.7449 - val_loss: 0.8194 - val_acc: 0.8037
# Epoch 23/50
# 7155/7155 [==============================] - 202s 28ms/step - loss: 1.2064 - acc: 0.7488 - val_loss: 0.8151 - val_acc: 0.8031
# Epoch 24/50
# 7155/7155 [==============================] - 201s 28ms/step - loss: 1.1640 - acc: 0.7551 - val_loss: 0.8083 - val_acc: 0.8057
# Epoch 25/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.1761 - acc: 0.7514 - val_loss: 0.7995 - val_acc: 0.8037
# Epoch 26/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.1987 - acc: 0.7431 - val_loss: 0.7943 - val_acc: 0.8014
# Epoch 27/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.1728 - acc: 0.7509 - val_loss: 0.7914 - val_acc: 0.8057
# Epoch 28/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.1586 - acc: 0.7546 - val_loss: 0.7894 - val_acc: 0.8109
# Epoch 29/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.1161 - acc: 0.7651 - val_loss: 0.7800 - val_acc: 0.7998
# Epoch 30/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.1173 - acc: 0.7609 - val_loss: 0.7785 - val_acc: 0.8037
# Epoch 31/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.1078 - acc: 0.7628 - val_loss: 0.7737 - val_acc: 0.8011
# Epoch 32/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.1068 - acc: 0.7638 - val_loss: 0.7756 - val_acc: 0.8031
# Epoch 33/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.0995 - acc: 0.7644 - val_loss: 0.7665 - val_acc: 0.8047
# Epoch 34/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.0931 - acc: 0.7653 - val_loss: 0.7637 - val_acc: 0.8014
# Epoch 35/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.1047 - acc: 0.7607 - val_loss: 0.7598 - val_acc: 0.8047
# Epoch 36/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.0989 - acc: 0.7637 - val_loss: 0.7587 - val_acc: 0.8018
# Epoch 37/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.0618 - acc: 0.7706 - val_loss: 0.7593 - val_acc: 0.8040
# Epoch 38/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.0667 - acc: 0.7723 - val_loss: 0.7562 - val_acc: 0.8018
# Epoch 39/50
# 7155/7155 [==============================] - 199s 28ms/step - loss: 1.0505 - acc: 0.7734 - val_loss: 0.7535 - val_acc: 0.8076
# Epoch 40/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.0579 - acc: 0.7718 - val_loss: 0.7506 - val_acc: 0.8047
# Epoch 41/50
# 7155/7155 [==============================] - 199s 28ms/step - loss: 1.0244 - acc: 0.7793 - val_loss: 0.7485 - val_acc: 0.8037
# Epoch 42/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.0396 - acc: 0.7741 - val_loss: 0.7502 - val_acc: 0.8034
# Epoch 43/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.0630 - acc: 0.7683 - val_loss: 0.7442 - val_acc: 0.8047
# Epoch 44/50
# 7155/7155 [==============================] - 199s 28ms/step - loss: 1.0028 - acc: 0.7838 - val_loss: 0.7441 - val_acc: 0.8018
# Epoch 45/50
# 7155/7155 [==============================] - 199s 28ms/step - loss: 1.0394 - acc: 0.7715 - val_loss: 0.7415 - val_acc: 0.8037
# Epoch 46/50
# 7155/7155 [==============================] - 199s 28ms/step - loss: 1.0371 - acc: 0.7722 - val_loss: 0.7401 - val_acc: 0.8060
# Epoch 47/50
# 7155/7155 [==============================] - 199s 28ms/step - loss: 1.0171 - acc: 0.7769 - val_loss: 0.7419 - val_acc: 0.8014
# Epoch 48/50
# 7155/7155 [==============================] - 199s 28ms/step - loss: 0.9878 - acc: 0.7860 - val_loss: 0.7391 - val_acc: 0.8037
# Epoch 49/50
# 7155/7155 [==============================] - 200s 28ms/step - loss: 1.0164 - acc: 0.7776 - val_loss: 0.7364 - val_acc: 0.8044
# Epoch 50/50
# 7155/7155 [==============================] - 140s 20ms/step - loss: 0.9889 - acc: 0.7825 - val_loss: 0.7407 - val_acc: 0.8034
# 3067/3067 [==============================] - 67s 22ms/step

# %%
preds = model.predict(x_test, verbose=1)

sub = pd.DataFrame(preds)
# Set column names to those generated by the one-hot encoding earlier
col_names = one_hot.columns.values
sub.columns = col_names
# Insert the column id from the sample_submission at the start of the data frame
sub.insert(0, 'id', df_test['id'])
sub.head(5)

sub.to_csv(directory_path+"result-9.csv", encoding='utf-8', index=False)
# Out:
# 10357/10357 [==============================] - 345s 33ms/step
